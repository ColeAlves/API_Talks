# %%
# !pip install --upgrade google-api-python-client
# !pip install pytube

# %%
import json
import urllib.request  #library used for opening urls 
import pprint

from pytube import YouTube

# %%
#this is opening a file with the API key so this can be ignored 
keyFile = open("EweTube.txt", "r")
#The API key 
apiKey = keyFile.read()

#https://developers.google.com/youtube/v3/quickstart/python

#videoID is the last several characters in the youtube link
videoID = "MHS-htjGgSY"

#f in prefix is a f-string or formatted string
url = f"https://www.googleapis.com/youtube/v3/videos?part=snippet&id={videoID}&key={apiKey}"

#opens the url link been given
jsonURL = urllib.request.urlopen(url)
data = json.loads(jsonURL.read())


pprint.pprint(data)
# Out:
# {'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/Sy98-JJ44OmpORqgap2JHQzktR8"',
#  'items': [{'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/SIOBGjLG-9vLCyiiKWuCmLDk1MU"',
#             'id': 'MHS-htjGgSY',
#             'kind': 'youtube#video',
#             'snippet': {'categoryId': '27',
#                         'channelId': 'UCZYTClx2T1of7BRZ86-8fow',
#                         'channelTitle': 'SciShow',
#                         'defaultAudioLanguage': 'en',
#                         'defaultLanguage': 'en',
#                         'description': 'With up to ten years in prison at '
#                                        'stake, will Wanda rat Fred out? Game '
#                                        'theory is looking at human '
#                                        'interactions through the lens of '
#                                        'mathematics.\n'
#                                        '\n'
#                                        'Hosted by: Hank Green\n'
#                                        '----------\n'
#                                        'Support SciShow by becoming a patron '
#                                        'on Patreon: '
#                                        'https://www.patreon.com/scishow\n'
#                                        '----------\n'
#                                        'Dooblydoo thanks go to the following '
#                                        "Patreon supporters -- we couldn't make "
#                                        'SciShow without them! Shout out to '
#                                        'Kevin Bealer, Justin Lentz, Mark '
#                                        'Terrio-Cameron, Patrick Merrithew, '
#                                        'Accalia Elementia, Fatima Iqbal, '
#                                        'Benny, Kyle Anderson, Mike Frayn, Tim '
#                                        'Curwick, Will and Sonja Marple, '
#                                        'Philippe von Bergen, Chris Peters, '
#                                        'Kathy Philip, Patrick D. Ashmore, '
#                                        'Thomas J., charles george, and Bader '
#                                        'AlGhamdi.\n'
#                                        '----------\n'
#                                        'Like SciShow? Want to help support us, '
#                                        'and also get things to put on your '
#                                        'walls, cover your torso and hold your '
#                                        'liquids? Check out our awesome '
#                                        'products over at DFTBA Records: '
#                                        'http://dftba.com/scishow\n'
#                                        '----------\n'
#                                        'Looking for SciShow elsewhere on the '
#                                        'internet?\n'
#                                        'Facebook: '
#                                        'http://www.facebook.com/scishow\n'
#                                        'Twitter: '
#                                        'http://www.twitter.com/scishow\n'
#                                        'Tumblr: http://scishow.tumblr.com\n'
#                                        'Instagram: '
#                                        'http://instagram.com/thescishow\n'
#                                        '----------\n'
#                                        'Sources:\n'
#                                        'https://www.khanacademy.org/economics-finance-domain/microeconomics/nash-equilibrium-tutorial\n'
#                                        'http://levine.sscnet.ucla.edu/general/whatis.htm\n'
#                                        'http://assets.cambridge.org/97805213/61774/sample/9780521361774ws.pdf\n'
#                                        'https://www.youtube.com/watch?v=qcLZMYPdpH4\n'
#                                        'http://link.springer.com/chapter/10.1007/978-1-349-20181-5_1\n'
#                                        'http://www.gametheory.net/dictionary/Game.html\n'
#                                        '\n'
#                                        'Image Links:\n'
#                                        'https://en.wikipedia.org/wiki/John_Forbes_Nash_Jr.',
#                         'liveBroadcastContent': 'none',
#                         'localized': {'description': 'With up to ten years in '
#                                                      'prison at stake, will '
#                                                      'Wanda rat Fred out? Game '
#                                                      'theory is looking at '
#                                                      'human interactions '
#                                                      'through the lens of '
#                                                      'mathematics.\n'
#                                                      '\n'
#                                                      'Hosted by: Hank Green\n'
#                                                      '----------\n'
#                                                      'Support SciShow by '
#                                                      'becoming a patron on '
#                                                      'Patreon: '
#                                                      'https://www.patreon.com/scishow\n'
#                                                      '----------\n'
#                                                      'Dooblydoo thanks go to '
#                                                      'the following Patreon '
#                                                      'supporters -- we '
#                                                      "couldn't make SciShow "
#                                                      'without them! Shout out '
#                                                      'to Kevin Bealer, Justin '
#                                                      'Lentz, Mark '
#                                                      'Terrio-Cameron, Patrick '
#                                                      'Merrithew, Accalia '
#                                                      'Elementia, Fatima Iqbal, '
#                                                      'Benny, Kyle Anderson, '
#                                                      'Mike Frayn, Tim Curwick, '
#                                                      'Will and Sonja Marple, '
#                                                      'Philippe von Bergen, '
#                                                      'Chris Peters, Kathy '
#                                                      'Philip, Patrick D. '
#                                                      'Ashmore, Thomas J., '
#                                                      'charles george, and '
#                                                      'Bader AlGhamdi.\n'
#                                                      '----------\n'
#                                                      'Like SciShow? Want to '
#                                                      'help support us, and '
#                                                      'also get things to put '
#                                                      'on your walls, cover '
#                                                      'your torso and hold your '
#                                                      'liquids? Check out our '
#                                                      'awesome products over at '
#                                                      'DFTBA Records: '
#                                                      'http://dftba.com/scishow\n'
#                                                      '----------\n'
#                                                      'Looking for SciShow '
#                                                      'elsewhere on the '
#                                                      'internet?\n'
#                                                      'Facebook: '
#                                                      'http://www.facebook.com/scishow\n'
#                                                      'Twitter: '
#                                                      'http://www.twitter.com/scishow\n'
#                                                      'Tumblr: '
#                                                      'http://scishow.tumblr.com\n'
#                                                      'Instagram: '
#                                                      'http://instagram.com/thescishow\n'
#                                                      '----------\n'
#                                                      'Sources:\n'
#                                                      'https://www.khanacademy.org/economics-finance-domain/microeconomics/nash-equilibrium-tutorial\n'
#                                                      'http://levine.sscnet.ucla.edu/general/whatis.htm\n'
#                                                      'http://assets.cambridge.org/97805213/61774/sample/9780521361774ws.pdf\n'
#                                                      'https://www.youtube.com/watch?v=qcLZMYPdpH4\n'
#                                                      'http://link.springer.com/chapter/10.1007/978-1-349-20181-5_1\n'
#                                                      'http://www.gametheory.net/dictionary/Game.html\n'
#                                                      '\n'
#                                                      'Image Links:\n'
#                                                      'https://en.wikipedia.org/wiki/John_Forbes_Nash_Jr.',
#                                       'title': 'Game Theory: The Science of '
#                                                'Decision-Making'},
#                         'publishedAt': '2016-09-29T21:00:00.000Z',
#                         'tags': ['SciShow',
#                                  'science',
#                                  'Hank',
#                                  'Green',
#                                  'education',
#                                  'learn',
#                                  'Game Theory: The Science of Decision-Making',
#                                  'John Nash',
#                                  'mathematics',
#                                  'Game Theory',
#                                  'interaction',
#                                  'human',
#                                  'cooperative',
#                                  'noncooperative',
#                                  "Prisoner's Dilemma",
#                                  'jail',
#                                  'prison',
#                                  'snitch',
#                                  'Nash Equilibrium',
#                                  'confess',
#                                  'competition',
#                                  'coalition',
#                                  'Shapley value',
#                                  'contribution',
#                                  'marginal contribution',
#                                  'axiom',
#                                  'cookies'],
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/MHS-htjGgSY/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/MHS-htjGgSY/hqdefault.jpg',
#                                                 'width': 480},
#                                        'maxres': {'height': 720,
#                                                   'url': 'https://i.ytimg.com/vi/MHS-htjGgSY/maxresdefault.jpg',
#                                                   'width': 1280},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/MHS-htjGgSY/mqdefault.jpg',
#                                                   'width': 320},
#                                        'standard': {'height': 480,
#                                                     'url': 'https://i.ytimg.com/vi/MHS-htjGgSY/sddefault.jpg',
#                                                     'width': 640}},
#                         'title': 'Game Theory: The Science of '
#                                  'Decision-Making'}}],
#  'kind': 'youtube#videoListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %%
#class to get the id from the youtube link
class Helper:
    def id_from_url(self, url: str):
        #rsplit() method returns a list of strings after breaking 
        #the given string from right side by the specified separator
        #https://www.geeksforgeeks.org/python-string-rsplit/
        return url.rsplit("=", 1)[1]
    
s = "https://www.youtube.com/watch?v=TUcO-wHldaU"    
helper = Helper()
print(helper.id_from_url(s))
# Out:
# TUcO-wHldaU
