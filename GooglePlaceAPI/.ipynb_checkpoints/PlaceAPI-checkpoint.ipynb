# %%
#The following lines have been runned on my environment
#The install googlemaps lets me import the library to use the api later to get information from google maps
#https://github.com/googlemaps/google-maps-services-python
# !pip install googlemaps

# %%
import googlemaps
import pprint
import time

# %%
#this is opening a file with the API key so this can be ignored 
keyFile = open("spartan.txt", "r")
#kFile is the API key 
kFile = keyFile.read()

#https://www.youtube.com/watch?v=qkSmuquMueA
#Set Google maps API Key
#This API key can be used for several API calls.  Geocoding, Geolocation, Places
#Client(*key = API_KEY)  *key = is needed 
gmaps_key = googlemaps.Client(key = kFile)

#Geocoding an address
geocode_result = gmaps_key.geocode('2079 Zumbehl Rd, St Charles, MO')
pprint.pprint(geocode_result)
# Look up an address with reverse geocoding
reverse_geocode_result = gmaps_key.reverse_geocode((38.815615, -90.552195))
pprint.pprint(reverse_geocode_result)

#The following link is documentation to the places api 
#https://developers.google.com/places/web-service/intro
# Out:
# [{'address_components': [{'long_name': '2957',
#                           'short_name': '2957',
#                           'types': ['street_number']},
#                          {'long_name': 'Wentworth Drive',
#                           'short_name': 'Wentworth Dr',
#                           'types': ['route']},
#                          {'long_name': 'Saint Charles',
#                           'short_name': 'St Charles',
#                           'types': ['locality', 'political']},
#                          {'long_name': 'Lindenwood Township',
#                           'short_name': 'Lindenwood Township',
#                           'types': ['administrative_area_level_3',
#                                     'political']},
#                          {'long_name': 'St. Charles County',
#                           'short_name': 'St Charles County',
#                           'types': ['administrative_area_level_2',
#                                     'political']},
#                          {'long_name': 'Missouri',
#                           'short_name': 'MO',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': 'United States',
#                           'short_name': 'US',
#                           'types': ['country', 'political']},
#                          {'long_name': '63301',
#                           'short_name': '63301',
#                           'types': ['postal_code']},
#                          {'long_name': '4555',
#                           'short_name': '4555',
#                           'types': ['postal_code_suffix']}],
#   'formatted_address': '2957 Wentworth Dr, St Charles, MO 63301, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 38.8055987, 'lng': -90.5323272},
#                           'southwest': {'lat': 38.8054541, 'lng': -90.5325663}},
#                'location': {'lat': 38.8055061, 'lng': -90.53244740000001},
#                'location_type': 'ROOFTOP',
#                'viewport': {'northeast': {'lat': 38.8068753802915,
#                                           'lng': -90.5310977697085},
#                             'southwest': {'lat': 38.8041774197085,
#                                           'lng': -90.53379573029152}}},
#   'place_id': 'ChIJh1UfG7Eo34cRagwpqqaCQOI',
#   'types': ['premise']}]

# %%
#Uses google places api to get the surrounding building of type in radius of XX meters
#https://developers.google.com/places/web-service/search
#https://developers.google.com/places/web-service/supported_types
places_result = gmaps_key.places_nearby(location = '38.885615, -90.532195', radius = 1000, open_now = False, type = 'restaurant') 

pprint.pprint(places_result)

#pause program of the page loads
#time.sleep(3)

#if there is not more than 20 results from the first search it will error out on this result
#places_result = gmaps_key.places_nearby(page_token = places_result['next_page_token']) 

#pprint.pprint(places_result)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCIQEAAPaZg6GhNzwhspBpaHi7Vw2t7rkqLhOSDaXWUHFg2fVg1rjp-UkggeEtQBnKW5RpABJMWmsUVZbrv9aWHNJYccS2vqTow1oX8G24jdscmq2zore_hXNiUXZl1VKarxbAAqBQSqYyjKZPOBzCj8YLoV9Y1kRczqIyNJTxhSCAqizAQ3aONHcj45ggHHTmtZlaUAFYBA8CnKKX1ZyidCdNp4H4HYv4jX05ps3oYZ5iE87Ok-XWNBAlmmyz4w-l7PoOAw1xbt9LrPFgj8ZsF9Zl-ju4HnDXL7X51WmXNGdGKuhW4idBbvnpMwPpv2LNPRnRQ6jitrGpjXngaLhOhz7e_UG80398en5_OzJ_rmhW96XGPPZYKAgyH_F3ru0k8Cvj3Saf-CQS9t__n6qLlNyNW8sSEISc1UGoC97Ujq7LIOC4dWEaFDbaYwqSDwrItQt5w9nCbekIaYRt',
#  'results': [{'geometry': {'location': {'lat': 38.778742, 'lng': -90.5183},
#                            'viewport': {'northeast': {'lat': 38.7801213802915,
#                                                       'lng': -90.5169145197085},
#                                         'southwest': {'lat': 38.77742341970851,
#                                                       'lng': -90.5196124802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '40d2e36ef36aa20e48bcecce9ce86336cd856564',
#               'name': 'Chuck E. Cheese',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100035173432132308836/photos">Chuck '
#                                                 'E. Cheese</a>'],
#                           'photo_reference': 'CmRaAAAAUMNGXBjgckIqbjN_rJQEPMxkcJXUaUtC_J3uBrS3o-ySsbgNwTQpb70WxVeXyQjyQHYw4DlJ47TurohReSrEICuXl9jxSH3jruBKAXOzo5Mlz-E1PuzdWub7NaBfMrAqEhCGtigg6vtN-CuRTwiSjtEjGhTO6pG7BmKBwRy4Wr9UHrHzvhq-jQ',
#                           'width': 1778}],
#               'place_id': 'ChIJFRAc6icv34cRupWuW9TN7f0',
#               'plus_code': {'compound_code': 'QFHJ+FM Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFQFHJ+FM'},
#               'price_level': 2,
#               'rating': 3.8,
#               'reference': 'ChIJFRAc6icv34cRupWuW9TN7f0',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 946,
#               'vicinity': '2669 Veterans Memorial Parkway, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.7845526, 'lng': -90.5295301},
#                            'viewport': {'northeast': {'lat': 38.78594828029149,
#                                                       'lng': -90.52824416970849},
#                                         'southwest': {'lat': 38.7832503197085,
#                                                       'lng': -90.5309421302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': 'eee21b0231be36132f50d034b873ee0637ba4ad3',
#               'name': 'Subway',
#               'opening_hours': {'open_now': True},
#               'place_id': 'ChIJKeE7ddMo34cRcPeCL86k3II',
#               'plus_code': {'compound_code': 'QFMC+R5 Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFQFMC+R5'},
#               'price_level': 1,
#               'rating': 4,
#               'reference': 'ChIJKeE7ddMo34cRcPeCL86k3II',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 34,
#               'vicinity': '1064 Regency Parkway, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.81973199999999,
#                                         'lng': -90.51467799999999},
#                            'viewport': {'northeast': {'lat': 38.8211458302915,
#                                                       'lng': -90.51327161970849},
#                                         'southwest': {'lat': 38.8184478697085,
#                                                       'lng': -90.5159695802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': '403ab6a4200ec9f4b3df43d8da9dc07e239add98',
#               'name': 'Subway',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1920,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102092751185013285690/photos">Tristan '
#                                                 'Shannon</a>'],
#                           'photo_reference': 'CmRaAAAAre42hzjG8O_QIcV09Aoikdy2PHdImf_oPgwPVkN9UnGWvm5rXRnAFRDNn13NtF4EvSohGIhRC0BhtIBopi3YhRH44z8BuyRRt4uaulctkwMeMVW53FMbSnV420Z4LPbREhCYPzcjHyTatx_s3omnUiKPGhRkJb3aK5ugCXHYpA9Wz3M2zVj_2A',
#                           'width': 1080}],
#               'place_id': 'ChIJs_aNJuUl34cRCBnrvKJ8NBI',
#               'plus_code': {'compound_code': 'RF9P+V4 Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFRF9P+V4'},
#               'price_level': 1,
#               'rating': 3.8,
#               'reference': 'ChIJs_aNJuUl34cRCBnrvKJ8NBI',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 56,
#               'vicinity': '3735 Elm Street, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.7953988, 'lng': -90.5742173},
#                            'viewport': {'northeast': {'lat': 38.7967629802915,
#                                                       'lng': -90.5729570197085},
#                                         'southwest': {'lat': 38.7940650197085,
#                                                       'lng': -90.57565498029152}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#               'id': '0b9b40c9130b1fcbd45fb8eb4feb6b0262d2ff2b',
#               'name': 'Shamrocks Pub n Grill',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2988,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109225854343953801978/photos">Don '
#                                                 'Handshy</a>'],
#                           'photo_reference': 'CmRaAAAAKAYj0JzA7BEcV7FnYzFNK-OKEF1w07DPL7_JKd7UXjNsOT_x1hNHOGG3ANVznMsY5Dq0Dphn80M4wBe_sori6W8DaTryHbtvHu25PynjKMgZySl5n9snQtujrF84qvduEhAWVWBnWNxRSUVeXF8DM3lpGhQyQSgjxuUUl7AoioG95SQfpt2M0w',
#                           'width': 5312}],
#               'place_id': 'ChIJnRChIUMo34cR7U7oB7U0s-8',
#               'plus_code': {'compound_code': 'QCWG+58 St. Peters, MO, United '
#                                              'States',
#                             'global_code': '86CFQCWG+58'},
#               'price_level': 2,
#               'rating': 4.4,
#               'reference': 'ChIJnRChIUMo34cR7U7oB7U0s-8',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 793,
#               'vicinity': '4177 Veterans Memorial Parkway, St. Peters'},
#              {'geometry': {'location': {'lat': 38.79509090000001,
#                                         'lng': -90.57229389999999},
#                            'viewport': {'northeast': {'lat': 38.7964732302915,
#                                                       'lng': -90.57110781970849},
#                                         'southwest': {'lat': 38.7937752697085,
#                                                       'lng': -90.5738057802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': '4182d5dc389eb91d4b7bc0530c93a2ec5773093b',
#               'name': 'Red Lobster',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115269114481709081363/photos">Melo '
#                                                 'Pretty Pink</a>'],
#                           'photo_reference': 'CmRaAAAAVgTke0A4sLc3n7cCrz7x3Djn1rSzuefY-fObjfAeRk4CfN8j2r0EsFNuCJVV5yInTa8uXOxETArRAoKfQ92cwQUFgfQvvyYz6zTf2dhaQF1f7ODO-8il-3b_VKTlSY2NEhAawiPwWgpPk9GD0TcSIwmWGhR01m-sJaenUOZCbB4Vm1fUoe3WDg',
#                           'width': 3024}],
#               'place_id': 'ChIJGx5H0Fwo34cR6omHNHRB7es',
#               'plus_code': {'compound_code': 'QCWH+23 St. Peters, MO, United '
#                                              'States',
#                             'global_code': '86CFQCWH+23'},
#               'price_level': 2,
#               'rating': 4.2,
#               'reference': 'ChIJGx5H0Fwo34cR6omHNHRB7es',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1417,
#               'vicinity': '4101 Veterans Memorial Parkway, St. Peters'},
#              {'geometry': {'location': {'lat': 38.7782803, 'lng': -90.5289209},
#                            'viewport': {'northeast': {'lat': 38.7797221302915,
#                                                       'lng': -90.5276587197085},
#                                         'southwest': {'lat': 38.7770241697085,
#                                                       'lng': -90.53035668029152}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': 'a09e937d98aeac5142502e3cd6bd74f92f96f837',
#               'name': 'Golden Corral Buffet & Grill',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 639,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115356483329190018312/photos">Golden '
#                                                 'Corral Buffet &amp; '
#                                                 'Grill</a>'],
#                           'photo_reference': 'CmRaAAAAClb_WBETbTW5Ozy_R2f3wCMB8egBjgP9L_g-Fm4Eo-zt2_g_9Zm7fmIdH50k59ouL_6chek8kvL6-rRuFQUAUxsaMyXg54-vOM9AZwnJmXewlwGt_y4PuPgVN_qlfKIdEhCE6KOulHfjCS9bbcsb4NDDGhSxcYK-SKWZywPfVCfzk4_wEEAXHg',
#                           'width': 960}],
#               'place_id': 'ChIJc_jtk9Uo34cRrJWHFXfNjxk',
#               'plus_code': {'compound_code': 'QFHC+8C Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFQFHC+8C'},
#               'price_level': 2,
#               'rating': 3.8,
#               'reference': 'ChIJc_jtk9Uo34cRrJWHFXfNjxk',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2417,
#               'vicinity': '1850 Zumbehl Road, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.7835006, 'lng': -90.5351772},
#                            'viewport': {'northeast': {'lat': 38.7848749802915,
#                                                       'lng': -90.53377926970849},
#                                         'southwest': {'lat': 38.7821770197085,
#                                                       'lng': -90.5364772302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': '9396d7ad8078645694aa1afcac1320add65e012b',
#               'name': "Fratelli's Ristorante",
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106478654167513494372/photos">Dave '
#                                                 'Miller</a>'],
#                           'photo_reference': 'CmRaAAAAG94YYYnznyXW1OH6dfUf6rt9_GvnEcrTRLgVlr_8EYYwzL-PqF6S3Pe9aAi-9wer0q5I382Hx42kUzYo95Ujvq1JDBoqHn9iLD-aLYe4j1bxQ2HEVtDwfbq4AMRjLvJKEhDTsTLMfHIzAWxzUvGtdcziGhS8vTuPD6dtK2tvi2BT4SpKghreoQ',
#                           'width': 4032}],
#               'place_id': 'ChIJtbzmpdAo34cR_0nGEwPNork',
#               'plus_code': {'compound_code': 'QFM7+CW Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFQFM7+CW'},
#               'price_level': 2,
#               'rating': 4.6,
#               'reference': 'ChIJtbzmpdAo34cR_0nGEwPNork',
#               'scope': 'GOOGLE',
#               'types': ['bakery',
#                         'meal_takeaway',
#                         'bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 574,
#               'vicinity': '2061 Zumbehl Road, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.7735828,
#                                         'lng': -90.51665489999999},
#                            'viewport': {'northeast': {'lat': 38.77509423029149,
#                                                       'lng': -90.5150907697085},
#                                         'southwest': {'lat': 38.77239626970849,
#                                                       'lng': -90.5177887302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': 'fc1c775c06fd872a28bcd32b068c3d82a39037b7',
#               'name': "Gingham's Homestyle Restaurant",
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 608,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113110749538882738946/photos">Gingham&#39;s '
#                                                 'Homestyle Restaurant</a>'],
#                           'photo_reference': 'CmRaAAAAql_siw12PkdcJ_ncEsGHPBnyid3B9ClPu1BMA6WTjB8CmFBbAccCBzmubHCmA0iUH-fEVZ987eDD4SEb55_Y4dZs9DptYPZYnVdbATmEkG7XqUHW0oxv_5msC5fnC5K2EhAT12A0EgAQ3lV1BJ7wtKnRGhSFnr8jcsP6K4-F8TnuPOzpcUv6Bg',
#                           'width': 1080}],
#               'place_id': 'ChIJpeNXZtcu34cRBtQ9ToYEFc8',
#               'plus_code': {'compound_code': 'QFFM+C8 Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFQFFM+C8'},
#               'price_level': 1,
#               'rating': 4.5,
#               'reference': 'ChIJpeNXZtcu34cRBtQ9ToYEFc8',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2613,
#               'vicinity': '1881 Sherman Drive, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.7892345,
#                                         'lng': -90.56524429999999},
#                            'viewport': {'northeast': {'lat': 38.79064373029149,
#                                                       'lng': -90.5638940697085},
#                                         'southwest': {'lat': 38.78794576970849,
#                                                       'lng': -90.5665920302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': '959bf0e1a539218ba1813f3b32a79a576a5031ec',
#               'name': "Culver's",
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2988,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115775383075385105760/photos">Jim '
#                                                 'F</a>'],
#                           'photo_reference': 'CmRaAAAAIexawpv-2Buz-uEVi2dDXFMRc5b6WvJdqRnBglvTgleLBWxTlhSJGNcbuk9aEASmjZNxGEG35ranRc2VQQ0PnCnAlA_8R0064tPw0mOln0VL7i_N2qcX8ScoY6psvImiEhCqi8LreosoArd7tVh_-Z41GhROlUUzb8bIQadLhbYD3V9r-mEi5g',
#                           'width': 5312}],
#               'place_id': 'ChIJd-ilR1go34cRYFZ3lqto-HM',
#               'plus_code': {'compound_code': 'QCQM+MW Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFQCQM+MW'},
#               'price_level': 1,
#               'rating': 4.3,
#               'reference': 'ChIJd-ilR1go34cRYFZ3lqto-HM',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 1041,
#               'vicinity': '2750 Muegge Road, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.8206917, 'lng': -90.5142221},
#                            'viewport': {'northeast': {'lat': 38.8220823302915,
#                                                       'lng': -90.5129323697085},
#                                         'southwest': {'lat': 38.8193843697085,
#                                                       'lng': -90.51563033029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': '8858bf750260fd747e7daa6a83fd090d4b5eb05b',
#               'name': "Imo's Pizza",
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 290,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111535915394052965254/photos">Imo&#39;s '
#                                                 'Pizza</a>'],
#                           'photo_reference': 'CmRaAAAAV6eJJanXBya6lqrZpUszxtVgfoOelINlB6YEoAP3dL8uYqkNBP2uGF3tE3t7JLHNoyjebd_hMHhecoS7WCRI2aKuPvP3a4UfrS0RhKlMg5WI1WNnSErlIKKbAiXY6H-bEhDESR1ZvhbfM2rjAmpJ0AH1GhSdbWYx4CYr1D-aIEZONP6XShP-3Q',
#                           'width': 512}],
#               'place_id': 'ChIJ9bh1JuUl34cRokocRfHmmBc',
#               'plus_code': {'compound_code': 'RFCP+78 Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFRFCP+78'},
#               'price_level': 2,
#               'rating': 4.2,
#               'reference': 'ChIJ9bh1JuUl34cRokocRfHmmBc',
#               'scope': 'GOOGLE',
#               'types': ['meal_delivery',
#                         'meal_takeaway',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 138,
#               'vicinity': '3742 Elm Street, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.7870572, 'lng': -90.5119418},
#                            'viewport': {'northeast': {'lat': 38.78845038029149,
#                                                       'lng': -90.5106305197085},
#                                         'southwest': {'lat': 38.78575241970849,
#                                                       'lng': -90.51332848029152}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': 'd76ae29b618aaa835686fb4a397b042aaadf91b8',
#               'name': "Domino's Pizza",
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 768,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107525159703485339753/photos">Domino&#39;s '
#                                                 'Pizza</a>'],
#                           'photo_reference': 'CmRaAAAAW0sFGJ8MlOCw_-rwjZLBqE-3bvVP0WVY6Pfks846biAGiahkXOi7-SsO_6ck6Jhbt6DGZQT5tncfy9quhKs3Y3VFdHrdO_JP6XstTyR1DbYN3QTByCVeh9K8qVEdM_bLEhAWyWPzXpGeLRw3GabmYA1PGhRmtppE3pk8mWuBZnzRtUvKeE0Ukg',
#                           'width': 1024}],
#               'place_id': 'ChIJsb9PuyQv34cR42aBGxafDuA',
#               'plus_code': {'compound_code': 'QFPQ+R6 Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFQFPQ+R6'},
#               'price_level': 1,
#               'rating': 3.9,
#               'reference': 'ChIJsb9PuyQv34cR42aBGxafDuA',
#               'scope': 'GOOGLE',
#               'types': ['meal_delivery',
#                         'meal_takeaway',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 144,
#               'vicinity': '2181 Droste Road, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.78522, 'lng': -90.5158},
#                            'viewport': {'northeast': {'lat': 38.7866327802915,
#                                                       'lng': -90.51441416970849},
#                                         'southwest': {'lat': 38.7839348197085,
#                                                       'lng': -90.5171121302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': '52de2cd4bfc49a51169d0282e9a07edce0c7ad21',
#               'name': "JJ's Restaurant",
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 336,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111379996123835387625/photos">JJ&#39;s '
#                                                 'Restaurant</a>'],
#                           'photo_reference': 'CmRaAAAAafZVSgN1zNwMW_IxXdi0gILCJf2YljS2Kref2BA-LAHFuigo8VXJhOke1sXXdaNq5fe7RCkcjTTJmEZxJRyBY5hrV4jqwCXPhOF1bzkg3XSe8UYuD3FDSrZ3qo8J4z44EhDwmQLzZB4x1tmGZtlWdP_rGhRW1m6EyE2UR6XnDIUbFbJD4eOyLA',
#                           'width': 599}],
#               'place_id': 'ChIJQc2WnCUv34cRKVJHzRmlbCk',
#               'plus_code': {'compound_code': 'QFPM+3M Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFQFPM+3M'},
#               'price_level': 1,
#               'rating': 4.4,
#               'reference': 'ChIJQc2WnCUv34cRKVJHzRmlbCk',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 651,
#               'vicinity': '1215 South Duchesne Drive, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.82140070000001,
#                                         'lng': -90.5140242},
#                            'viewport': {'northeast': {'lat': 38.8227274802915,
#                                                       'lng': -90.5126348197085},
#                                         'southwest': {'lat': 38.82002951970851,
#                                                       'lng': -90.5153327802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': '19509db1e60cbc5b80b80af9bf30bcc5d4b0fbfd',
#               'name': "Jimmy John's",
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2988,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116214828446271697490/photos">John '
#                                                 'Melvin</a>'],
#                           'photo_reference': 'CmRaAAAApMgMlBOQrhTIYrAcRO3Iw1HXJ_JmDSFyjEF-ZhN61ECGcFtraaWTzWySKmg9YkVygnVfEeVXv0B65GnLZSkFzsEMjvOxaBbjrKqBrN-zslj1U99-mGowG89U0u6p_g9rEhCp3NYKkBdpf6tjuFYpBXCxGhTuo365DfA8IoMbDqZ2kRE5TDHMfA',
#                           'width': 5312}],
#               'place_id': 'ChIJcxOUpfcl34cRgYPd-dJkV-g',
#               'plus_code': {'compound_code': 'RFCP+H9 Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFRFCP+H9'},
#               'price_level': 1,
#               'rating': 4,
#               'reference': 'ChIJcxOUpfcl34cRgYPd-dJkV-g',
#               'scope': 'GOOGLE',
#               'types': ['meal_delivery',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 57,
#               'vicinity': '3754 Elm Street, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.7914924, 'lng': -90.5622047},
#                            'viewport': {'northeast': {'lat': 38.7928305802915,
#                                                       'lng': -90.5607729197085},
#                                         'southwest': {'lat': 38.7901326197085,
#                                                       'lng': -90.5634708802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': 'a446068b5fa9c1ec2f576aded11fa1c76d862700',
#               'name': 'IHOP',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 547,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106819409158516932101/photos">IHOP</a>'],
#                           'photo_reference': 'CmRaAAAAMzer6ER_Qj7LcxSQSEhis-yazUMpsThV5B1G-CGcJwAA6l0k_vFDunKTzxhV5GldplI9F1UGZqpE2hinIQ7aKX3ZH8HkmcUTK3ElV9vaWin4ZjKsSgoqvnyZpGED6M-oEhCw6TmRaU1ZsSXyQUWFXLB7GhS5YkvQOEpCz1QRzvo9fqFTmKoAOA',
#                           'width': 972}],
#               'place_id': 'ChIJvy4psOrX3ocRCJymBC5e-OA',
#               'plus_code': {'compound_code': 'QCRQ+H4 St. Peters, MO, United '
#                                              'States',
#                             'global_code': '86CFQCRQ+H4'},
#               'price_level': 1,
#               'rating': 4.1,
#               'reference': 'ChIJvy4psOrX3ocRCJymBC5e-OA',
#               'scope': 'GOOGLE',
#               'types': ['bakery',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 929,
#               'vicinity': "3851 Veteran'S Memorial Pkwy, St. Peters"},
#              {'geometry': {'location': {'lat': 38.8198649, 'lng': -90.5148916},
#                            'viewport': {'northeast': {'lat': 38.8212725802915,
#                                                       'lng': -90.51349066970849},
#                                         'southwest': {'lat': 38.8185746197085,
#                                                       'lng': -90.5161886302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': 'c0f1d0f925a27bfc6e551bc452ca0ee5226cd23c',
#               'name': 'China King Buffet',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 2448,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108045855884958828943/photos">Daniel '
#                                                 'Layer</a>'],
#                           'photo_reference': 'CmRaAAAAntFR0cn9U2QNKJU6q6d1dBfF7aEuagzt1G0fqjMN6nwvixBEL2OSkUdWRYRh5JcJDxNX4YbHfsgebzmWc56IWur1SnTqbHC2hQJFInwSbi6Z-kW3JV49eonI-SqHsvmmEhA-eN7ZiiqJLBZNFHyiEHgWGhTUnjbX6snb6Cnu4fpKD8EfVZZgkA',
#                           'width': 3264}],
#               'place_id': 'ChIJw3FsJuUl34cREnTBEiJfUqg',
#               'plus_code': {'compound_code': 'RF9P+W2 Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFRF9P+W2'},
#               'price_level': 1,
#               'rating': 3.5,
#               'reference': 'ChIJw3FsJuUl34cREnTBEiJfUqg',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 233,
#               'vicinity': '3743 Elm Street, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.78417810000001,
#                                         'lng': -90.5270184},
#                            'viewport': {'northeast': {'lat': 38.7854780302915,
#                                                       'lng': -90.52557346970849},
#                                         'southwest': {'lat': 38.7827800697085,
#                                                       'lng': -90.52827143029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': '85f70faae1dc0ff0a1d2cfe4ed455e8145469520',
#               'name': "Applebee's Grill + Bar",
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2304,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117318425814533993245/photos">Kathy '
#                                                 'Grubbs</a>'],
#                           'photo_reference': 'CmRaAAAA4mrSUkpoGHpwLQ-JBF8EEFhTBAKxhwnLEqLjiyR4X-yCXMpoZPpVHtezv49A3RSs-wMx80jk4X84l7EGtQ01d4ineRGGW6M7nOfJWDqeaneiFHH19KdaxQgTq51RECvXEhDkixrINj4wiQJh1GfjEGD7GhSSBWG9YhNP4iITbaoJ_UaKVcLSNw',
#                           'width': 4096}],
#               'place_id': 'ChIJgW0BFdMo34cRK2ow7wkweKY',
#               'plus_code': {'compound_code': 'QFMF+M5 Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFQFMF+M5'},
#               'price_level': 2,
#               'rating': 4.1,
#               'reference': 'ChIJgW0BFdMo34cRK2ow7wkweKY',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'bar',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 568,
#               'vicinity': '2921 South Service Road, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.7942326, 'lng': -90.568883},
#                            'viewport': {'northeast': {'lat': 38.7955216302915,
#                                                       'lng': -90.56746126970849},
#                                         'southwest': {'lat': 38.7928236697085,
#                                                       'lng': -90.57015923029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': '07eee8363bdcb00705950b9923e4c9e40301a12a',
#               'name': 'LongHorn Steakhouse',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106534303233452937372/photos">LongHorn '
#                                                 'Steakhouse</a>'],
#                           'photo_reference': 'CmRaAAAAJB41hGgh9dSNakBsHDZrTV5DbQ5njTqZkFg6XRCISpCUrnal002hefjaJxhUTKCeG4c6YCcpyQkm98MOxadjgSrrOdH7Vr9JrCvS43EnTswQ9TwAAjeEJ1HogF32sHMDEhDmpAan245lxhng_cdBumc8GhRR6NegyrwD6PZXNoiBWk9c_iougw',
#                           'width': 1000}],
#               'place_id': 'ChIJ73cWGFwo34cRxKTwxDjRZW8',
#               'plus_code': {'compound_code': 'QCVJ+MC St. Peters, MO, United '
#                                              'States',
#                             'global_code': '86CFQCVJ+MC'},
#               'price_level': 2,
#               'rating': 4.3,
#               'reference': 'ChIJ73cWGFwo34cRxKTwxDjRZW8',
#               'scope': 'GOOGLE',
#               'types': ['meal_takeaway',
#                         'bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 500,
#               'vicinity': '3979 Veterans Memorial Parkway, St. Peters'},
#              {'geometry': {'location': {'lat': 38.769892, 'lng': -90.5209495},
#                            'viewport': {'northeast': {'lat': 38.7712859302915,
#                                                       'lng': -90.5196707697085},
#                                         'southwest': {'lat': 38.7685879697085,
#                                                       'lng': -90.5223687302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': '6687dace4abf6fe79f48704c0d562ed56fd85b41',
#               'name': "McAlister's Deli",
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1960,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115920212675274930707/photos">Pamela '
#                                                 'Upton</a>'],
#                           'photo_reference': 'CmRaAAAAETECgzgzi1gkthfKJe7dUH8hyCtVCcnFBgEQ51NdrefMNYFggeoDd5OEYa3ZOLvDquXcmicn176TohEUFOhzJ2KJB4oWhCfpFERt14xF7x2wLxBwFThJf6528rg7XARVEhBAmiSi56bVSXiNoPI6DzlBGhR4NY6ieJm9C8rNhPGPDX-ndUcbSg',
#                           'width': 4032}],
#               'place_id': 'ChIJVZZJRdIu34cRfFrbwKz6RTM',
#               'plus_code': {'compound_code': 'QF9H+XJ Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFQF9H+XJ'},
#               'price_level': 2,
#               'rating': 4.3,
#               'reference': 'ChIJVZZJRdIu34cRfFrbwKz6RTM',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 642,
#               'vicinity': '1598 Country Club Plaza Drive, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.7850964,
#                                         'lng': -90.51159369999999},
#                            'viewport': {'northeast': {'lat': 38.78635853029149,
#                                                       'lng': -90.5102648697085},
#                                         'southwest': {'lat': 38.78366056970849,
#                                                       'lng': -90.51296283029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': '06caf1a94e413b6398890eeb546cbf5e80ffc96f',
#               'name': 'Pizza Hut',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 683,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112338655228303248522/photos">Pizza '
#                                                 'Hut</a>'],
#                           'photo_reference': 'CmRaAAAA-RmsJGNVdvfbgLUZfdN9d91hYae6MuyQxLDZT2ZhtDuIJiI8a58ybJ7CSPdFPNHdjK10EOa5CaSVSsVTVn9yYpgAv-3bBZKdNMmj280CqBugz9SCmiiKXflqsMeV1pUwEhBxB2tVZnjWdlvFle7D__nJGhRoGWRja9Y2mJIP4DNgvdPh8E67Iw',
#                           'width': 1025}],
#               'place_id': 'ChIJU_dZCyQv34cRC9_WfkpXj6w',
#               'plus_code': {'compound_code': 'QFPQ+29 Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFQFPQ+29'},
#               'price_level': 1,
#               'rating': 3.1,
#               'reference': 'ChIJU_dZCyQv34cRC9_WfkpXj6w',
#               'scope': 'GOOGLE',
#               'types': ['meal_takeaway',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 88,
#               'vicinity': '2440 West Clay Street, Saint Charles'},
#              {'geometry': {'location': {'lat': 38.7691088,
#                                         'lng': -90.52172279999999},
#                            'viewport': {'northeast': {'lat': 38.7705065802915,
#                                                       'lng': -90.52046556970849},
#                                         'southwest': {'lat': 38.7678086197085,
#                                                       'lng': -90.5231635302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#               'id': '25653409f0e93491605a036619b89c175c3dae62',
#               'name': 'Hotshots Sports Bar & Grill',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1440,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107772323946518621612/photos">Hotshots '
#                                                 'Sports Bar &amp; Grill</a>'],
#                           'photo_reference': 'CmRaAAAAyWcBMzUSkOGo_uAa2HrHAUBsccKKife5EdCB3bUbIe5ZLsXsS4qNSiCD-KYtPXXfNiYqMgwrwx2DaAF2IRtdNJbtk4RBqNgUyeSArE7N-WeL9-vxqeQ3j3jzR4NXqc00EhBAEeaeCJfUaUqW5WPX5G-YGhTA5b2Bl_vG7KronqQlRx5HT3XO-w',
#                           'width': 2560}],
#               'place_id': 'ChIJjfhBQtIu34cRIMBgFutV7q4',
#               'plus_code': {'compound_code': 'QF9H+J8 Saint Charles, Missouri, '
#                                              'United States',
#                             'global_code': '86CFQF9H+J8'},
#               'rating': 4,
#               'reference': 'ChIJjfhBQtIu34cRIMBgFutV7q4',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 455,
#               'vicinity': '1636 Country Club Plaza Drive, Saint Charles'}],
#  'status': 'OK'}

# %%
for place in places_result['results']:
    
    #define place id
    my_place_id = place['place_id']
    
    #define fields we want sent back to us
    #https://developers.google.com/places/web-service/details
    my_fields = ['name', 'type', 'vicinity']
    
    #make a request for the details
    place_details = gmaps_key.place(place_id = my_place_id, fields = my_fields)
    
    pprint.pprint(place_details)
# Out:
# {'html_attributions': [],
#  'result': {'name': 'Chuck E. Cheese',
#             'types': ['restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '2669 Veterans Memorial Parkway, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'Subway',
#             'types': ['restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '1064 Regency Parkway, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'Subway',
#             'types': ['restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '3735 Elm Street, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'Shamrocks Pub n Grill',
#             'types': ['bar',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '4177 Veterans Memorial Parkway, St. Peters'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'Red Lobster',
#             'types': ['bar',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '4101 Veterans Memorial Parkway, St. Peters'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'Golden Corral Buffet & Grill',
#             'types': ['restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '1850 Zumbehl Road, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': "Fratelli's Ristorante",
#             'types': ['bakery',
#                       'meal_takeaway',
#                       'bar',
#                       'store',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '2061 Zumbehl Road, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': "Gingham's Homestyle Restaurant",
#             'types': ['restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '1881 Sherman Drive, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': "Culver's",
#             'types': ['store',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '2750 Muegge Road, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': "Imo's Pizza",
#             'types': ['meal_delivery',
#                       'meal_takeaway',
#                       'store',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '3742 Elm Street, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': "Domino's Pizza",
#             'types': ['meal_delivery',
#                       'meal_takeaway',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '2181 Droste Road, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': "JJ's Restaurant",
#             'types': ['restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '1215 South Duchesne Drive, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': "Jimmy John's",
#             'types': ['meal_delivery',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '3754 Elm Street, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'IHOP',
#             'types': ['bakery',
#                       'store',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': "3851 Veteran'S Memorial Pkwy, St. Peters"},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'China King Buffet',
#             'types': ['restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '3743 Elm Street, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': "Applebee's Grill + Bar",
#             'types': ['restaurant',
#                       'bar',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '2921 South Service Road, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'LongHorn Steakhouse',
#             'types': ['meal_takeaway',
#                       'bar',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '3979 Veterans Memorial Parkway, St. Peters'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': "McAlister's Deli",
#             'types': ['store',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '1598 Country Club Plaza Drive, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'Pizza Hut',
#             'types': ['meal_takeaway',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '2440 West Clay Street, Saint Charles'},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'Hotshots Sports Bar & Grill',
#             'types': ['bar',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'vicinity': '1636 Country Club Plaza Drive, Saint Charles'},
#  'status': 'OK'}
